# %%
#Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns #Understanding my variables

datafile = pd.read_csv("Gay_Travel_Index_2012-2021.csv", sep=",")

# %%
#datafile[['Antidiscrimination_Legislation']] = datafile[['Antidiscrimination_Legislation']].apply(pd.to_numeric)

datafile.info()
print(datafile.describe())
datafile.corr(numeric_only=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1773 entries, 0 to 1772
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CountryIndex                    1773 non-null   int64
#  1   Country                         1773 non-null   object
#  2   Ranking                         1773 non-null   int64
#  3   Year                            1773 non-null   int64
#  4   Score                           1773 non-null   int64
#  5   Antidiscrimination_Legislation  1767 non-null   float64
#  6   Marriage_or_Civil Partnership   1770 non-null   float64
#  7   Adoption_Allowed                1770 non-null   float64
#  8   LGBT_Marketing                  1392 non-null   float64
#  9    Equal_Age_of Consent           1773 non-null   int64
#  10  Religious_Influence             1767 non-null   float64
#  11  HIV_Travel_Restrictions         1749 non-null   float64
# ...

# %%
from pandas.plotting import  scatter_matrix
attributes = ['Score', 'GDP', 'Ranking', 'Trans_Gender_Rights','Intersex_3rd_Option']
scatter_matrix(datafile[attributes])
# Out:
# array([[<AxesSubplot: xlabel='Score', ylabel='Score'>,
#         <AxesSubplot: xlabel='GDP', ylabel='Score'>,
#         <AxesSubplot: xlabel='Ranking', ylabel='Score'>,
#         <AxesSubplot: xlabel='Trans_Gender_Rights', ylabel='Score'>,
#         <AxesSubplot: xlabel='Intersex_3rd_Option', ylabel='Score'>],
#        [<AxesSubplot: xlabel='Score', ylabel='GDP'>,
#         <AxesSubplot: xlabel='GDP', ylabel='GDP'>,
#         <AxesSubplot: xlabel='Ranking', ylabel='GDP'>,
#         <AxesSubplot: xlabel='Trans_Gender_Rights', ylabel='GDP'>,
#         <AxesSubplot: xlabel='Intersex_3rd_Option', ylabel='GDP'>],
#        [<AxesSubplot: xlabel='Score', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='GDP', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='Ranking', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='Trans_Gender_Rights', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='Intersex_3rd_Option', ylabel='Ranking'>],
# ...

# %%
attributes_neg = ['Death_Sentence', 'Religious_Influence','Locals_Hostile','Conversion_Therapy']
scatter_matrix(datafile[attributes_neg])
# Out:
# array([[<AxesSubplot: xlabel='Death_Sentence', ylabel='Death_Sentence'>,
#         <AxesSubplot: xlabel='Religious_Influence', ylabel='Death_Sentence'>,
#         <AxesSubplot: xlabel='Locals_Hostile', ylabel='Death_Sentence'>,
#         <AxesSubplot: xlabel='Conversion_Therapy', ylabel='Death_Sentence'>],
#        [<AxesSubplot: xlabel='Death_Sentence', ylabel='Religious_Influence'>,
#         <AxesSubplot: xlabel='Religious_Influence', ylabel='Religious_Influence'>,
#         <AxesSubplot: xlabel='Locals_Hostile', ylabel='Religious_Influence'>,
#         <AxesSubplot: xlabel='Conversion_Therapy', ylabel='Religious_Influence'>],
#        [<AxesSubplot: xlabel='Death_Sentence', ylabel='Locals_Hostile'>,
#         <AxesSubplot: xlabel='Religious_Influence', ylabel='Locals_Hostile'>,
#         <AxesSubplot: xlabel='Locals_Hostile', ylabel='Locals_Hostile'>,
#         <AxesSubplot: xlabel='Conversion_Therapy', ylabel='Locals_Hostile'>],
# ...

# %%
import sklearn
from sklearn import preprocessing
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#scaler.fit(datafile.drop('Score',axis=4))

# %%
df2021 = datafile[datafile['Year'] > 2020]

# %%
attributes = ['Score', 'GDP', 'Ranking', 'Trans_Gender_Rights','Intersex_3rd_Option']
scatter_matrix(datafile[attributes])
# Out:
# array([[<AxesSubplot: xlabel='Score', ylabel='Score'>,
#         <AxesSubplot: xlabel='GDP', ylabel='Score'>,
#         <AxesSubplot: xlabel='Ranking', ylabel='Score'>,
#         <AxesSubplot: xlabel='Trans_Gender_Rights', ylabel='Score'>,
#         <AxesSubplot: xlabel='Intersex_3rd_Option', ylabel='Score'>],
#        [<AxesSubplot: xlabel='Score', ylabel='GDP'>,
#         <AxesSubplot: xlabel='GDP', ylabel='GDP'>,
#         <AxesSubplot: xlabel='Ranking', ylabel='GDP'>,
#         <AxesSubplot: xlabel='Trans_Gender_Rights', ylabel='GDP'>,
#         <AxesSubplot: xlabel='Intersex_3rd_Option', ylabel='GDP'>],
#        [<AxesSubplot: xlabel='Score', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='GDP', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='Ranking', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='Trans_Gender_Rights', ylabel='Ranking'>,
#         <AxesSubplot: xlabel='Intersex_3rd_Option', ylabel='Ranking'>],
# ...
